# %% [markdown]
# ## Environment setup

# %%
#Install packages. WARNING: if you run this on windows platform install 'pytorch' 
#!pip install nltk==3.7 pandas scipy==1.10.1 fasttext==0.9.2 gensim==4.3.2 scikit-learn==1.5.0 torch --quiet

# %% [markdown]
# We need a Facebook MUSE library to embedding alignment. You can only get this by cloning the Github repository into the project.
# Go to the project folder and run the following command in the console:
#
#     git clone https://github.com/facebookresearch/MUSE
#
# After you have cloned it, go to the MUSE/src/utils.py file and change 'fastText' to 'fasttext' in lines 76 and 80 (i.e. change the capital T to t), otherwise the code will crash. Run the Muse script for alignment of embeddings from the previous step (CAUTION: Replace slashes with backslashes in the path specification if you have a Windows platform):

# %%
# Clone the Facebook MUSE repository into the current directory:
#!git clone https://github.com/facebookresearch/MUSE

#!sed -i 's/import fastText/import fasttext/' MUSE/src/utils.py
#!sed -i 's/return fastText\.load_model/return fasttext.load_model/' MUSE/src/utils.py
# Out:
# Cloning into 'MUSE'...

# %% [markdown]
# # Library Imports

# %%
import fasttext
import nltk

# %% [markdown]
# # Dataset Generation

# %%
#Create datasets for embedding training and dictionaries for embedding alignement
def get_datasets():

    pd_file = open('input/pd.txt', 'w', encoding="utf8")
    cr_file = open('input/cr.txt', 'w', encoding="utf8")

    with open('input/C_merged_PD_in_CR_trunc_clean.txt', 'r', encoding='utf8') as f:
        vocab = {}
        for line in f:
            if len(line.strip()) > 0:
                id = line.split()[0]
                c = line.split()[1]
                text = " ".join(line.split()[2:]).strip()
                text = " ".join(nltk.wordpunct_tokenize(text)).lower()

                if c == "!CR":
                    cr_file.write(text + '\n')
                    words = text.split()
                    for w in words:
                        if w in vocab:
                            vocab[w][0] += 1
                        else:
                            vocab[w] = [1, 0]
                elif c == "!PD":
                    pd_file.write(text + '\n')
                    words = text.split()
                    for w in words:
                        if w in vocab:
                            vocab[w][1] += 1
                        else:
                            vocab[w] = [0, 1]
        pd_file.close()
        cr_file.close()
    words = []
    for word, freq in vocab.items():
        if freq[0] > 0 and freq[1] > 2:
            words.append((word, freq[0], freq[1]))

    words = sorted(words, reverse=True, key= lambda x: x[-1])
    train = open('input/en_en_dict_train.txt', 'w', encoding='utf8')
    test = open('input/en_en_dict_test.txt', 'w', encoding='utf8')

    counter = 0
    for w, f1, f2, in words[:5000]:
        if counter % 3 == 0:
            test.write(w + '\t' + w + '\n')
        else:
            train.write(w + '\t' + w + '\n')
        counter += 1
    train.close()
    test.close()


get_datasets()

# %% [markdown]
# # Embedding Learning

# %%
def make_embeddings(input, output):
    with open(input, "r", encoding="utf8") as f:
        text = " ".join(nltk.wordpunct_tokenize(f.read())).lower()
    filename = input.split('.')[0] + "_preprocessed." +  input.split('.')[1]
    with open(filename, "w", encoding="utf8") as f:
        f.write(text)
    model = fasttext.train_unsupervised(filename, min_count=6, model='skipgram')
    model.save_model(output + ".bin")

make_embeddings('input/pd.txt', 'embeddings/pd')
make_embeddings('input/cr.txt', 'embeddings/cr')

# %% [markdown]
# # Embedding Alignment

# %%
# !python MUSE/supervised.py --src_lang "cr" --tgt_lang "pd" --emb_dim 100 --max_vocab -1 --n_refinement 20 --dico_train "input/en_en_dict_train.txt" --dico_eval "input/en_en_dict_test.txt" --src_emb  "embeddings/cr.bin" --tgt_emb  "embeddings/pd.bin" --cuda 0
# Out:
# Impossible to import Faiss-GPU. Switching to FAISS-CPU, this will be slower.
#
# INFO - 03/14/25 14:24:35 - 0:00:00 - ============ Initialized logger ============
# INFO - 03/14/25 14:24:35 - 0:00:00 - cuda: False
#                                      dico_build: S2T&T2S
#                                      dico_eval: input/en_en_dict_test.txt
#                                      dico_max_rank: 10000
#                                      dico_max_size: 0
#                                      dico_method: csls_knn_10
#                                      dico_min_size: 0
#                                      dico_threshold: 0
#                                      dico_train: input/en_en_dict_train.txt
#                                      emb_dim: 100
#                                      exp_id:
#                                      exp_name: debug
#                                      exp_path: C:\Work\lbd-book-code\notebooks\MUSE\dumped\debug\z3krltoevw
#                                      export: txt
#                                      max_vocab: -1
#                                      n_refinement: 20
#                                      normalize_embeddings:
#                                      seed: -1
#                                      src_emb: embeddings/cr.bin
#                                      src_lang: cr
#                                      tgt_emb: embeddings/pd.bin
#                                      tgt_lang: pd
#                                      verbose: 2
# INFO - 03/14/25 14:24:35 - 0:00:00 - The experiment will be stored in C:\Work\lbd-book-code\notebooks\MUSE\dumped\debug\z3krltoevw
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# INFO - 03/14/25 14:24:36 - 0:00:01 - Loaded binary model. Generating embeddings ...
# INFO - 03/14/25 14:24:36 - 0:00:01 - Generated embeddings for 10026 words.
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# INFO - 03/14/25 14:24:38 - 0:00:02 - Loaded binary model. Generating embeddings ...
# INFO - 03/14/25 14:24:38 - 0:00:03 - Generated embeddings for 9370 words.
# INFO - 03/14/25 14:24:38 - 0:00:03 - Found 2716 pairs of words in the dictionary (2716 unique). 617 other pairs contained at least one unknown word (617 in lang1, 0 in lang2)
# INFO - 03/14/25 14:24:38 - 0:00:03 - Validation metric: precision_at_1-csls_knn_10
# INFO - 03/14/25 14:24:38 - 0:00:03 - Starting iteration 0...
# INFO - 03/14/25 14:24:38 - 0:00:03 - Found 1345 pairs of words in the dictionary (1345 unique). 322 other pairs contained at least one unknown word (322 in lang1, 0 in lang2)
# INFO - 03/14/25 14:24:38 - 0:00:03 - 1345 source words - nn - Precision at k = 1: 33.234201
# INFO - 03/14/25 14:24:38 - 0:00:03 - 1345 source words - nn - Precision at k = 5: 51.672862
# INFO - 03/14/25 14:24:38 - 0:00:03 - 1345 source words - nn - Precision at k = 10: 58.364312
# INFO - 03/14/25 14:24:38 - 0:00:03 - Found 1345 pairs of words in the dictionary (1345 unique). 322 other pairs contained at least one unknown word (322 in lang1, 0 in lang2)
# INFO - 03/14/25 14:24:38 - 0:00:03 - 1345 source words - csls_knn_10 - Precision at k = 1: 41.933086
# INFO - 03/14/25 14:24:38 - 0:00:03 - 1345 source words - csls_knn_10 - Precision at k = 5: 60.148699
# INFO - 03/14/25 14:24:38 - 0:00:03 - 1345 source words - csls_knn_10 - Precision at k = 10: 66.914498
# INFO - 03/14/25 14:24:39 - 0:00:04 - Building the train dictionary ...
# INFO - 03/14/25 14:24:39 - 0:00:04 - New train dictionary of 10000 pairs.
# INFO - 03/14/25 14:24:39 - 0:00:04 - Mean cosine (nn method, S2T build, 10000 max size): 0.67649
# INFO - 03/14/25 14:24:40 - 0:00:05 - Building the train dictionary ...
# INFO - 03/14/25 14:24:40 - 0:00:05 - New train dictionary of 10000 pairs.
# INFO - 03/14/25 14:24:40 - 0:00:05 - Mean cosine (csls_knn_10 method, S2T build, 10000 max size): 0
- New train dictionary of 10000 pairs.
# INFO - 03/14/25 14:25:45 - 0:01:10 - Mean cosine (nn method, S2T build, 10000 max size): 0.69991
# INFO - 03/14/25 14:25:46 - 0:01:11 - Building the train dictionary ...
# INFO - 03/14/25 14:25:46 - 0:01:11 - New train dictionary of 10000 pairs.
# INFO - 03/14/25 14:25:46 - 0:01:11 - Mean cosine (csls_knn_10 method, S2T build, 10000 max size): 0.69098
# INFO - 03/14/25 14:25:46 - 0:01:11 - __log__:{"n_iter": 20, "precision_at_1-nn": 29.5910780669145, "precision_at_5-nn": 45.57620817843866, "precision_at_10-nn": 50.48327137546469, "precision_at_1-csls_knn_10": 36.43122676579926, "precision_at_5-csls_knn_10": 51.37546468401487, "precision_at_10-csls_knn_10": 56.57992565055762, "mean_cosine-nn-S2T-10000": 0.6999086141586304, "mean_cosine-csls_knn_10-S2T-10000": 0.6909826993942261}
# INFO - 03/14/25 14:25:46 - 0:01:11 - End of iteration 20.
#
#
# INFO - 03/14/25 14:25:46 - 0:01:11 - * Reloading the best model from C:\Work\lbd-book-code\notebooks\MUSE\dumped\debug\z3krltoevw\best_mapping.pth ...
# INFO - 03/14/25 14:25:46 - 0:01:11 - Reloading all embeddings for mapping ...
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# INFO - 03/14/25 14:25:48 - 0:01:13 - Loaded binary model. Generating embeddings ...
# INFO - 03/14/25 14:25:48 - 0:01:13 - Generated embeddings for 10026 words.
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# INFO - 03/14/25 14:25:49 - 0:01:14 - Loaded binary model. Generating embeddings ...
# INFO - 03/14/25 14:25:50 - 0:01:14 - Generated embeddings for 9370 words.
# INFO - 03/14/25 14:25:50 - 0:01:14 - Map source embeddings to the target space ...
# c:\Work\lbd-book-code\notebooks\MUSE\src\trainer.py:262: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   x = Variable(src_emb[k:k + bs], volatile=True)
# INFO - 03/14/25 14:25:50 - 0:01:14 - Writing source embeddings to C:\Work\lbd-book-code\notebooks\MUSE\dumped\debug\z3krltoevw\vectors-cr.txt ...
# INFO - 03/14/25 14:25:52 - 0:01:17 - Writing target embeddings to C:\Work\lbd-book-code\notebooks\MUSE\dumped\debug\z3krltoevw\vectors-pd.txt ...

# %% [markdown]
# The aligned embedding models appear in the folder ./MUSE/dumped/debug/some_random_seed. Go to this folder and copy the files 'vectors-cr.txt' and 'vectors-pd.txt' into the folder 'embedding'.

# %%
#!LATEST_FOLDER=$(find MUSE/dumped/debug -type d -print0 | xargs -0 ls -td | head -n 1) && \
#cp "$LATEST_FOLDER/vectors-cr.txt" "$LATEST_FOLDER/vectors-pd.txt" embeddings/ && \
#echo "Files copied to embeddings/" || echo "Error: Files not found in the latest folder."
# Out:
# '$LATEST_FOLDER' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# In the last step, we try to find new relationships between genes in the plant defense domain using the aligned models by using the seed relationships from the circadian rhythm domain. For each seed relationship, we obtain the 10 closest relationships according to the cosine similarity of genes in the plant defense domain for each seed relation.

# %%
import numpy as np
import io
from sklearn.metrics.pairwise import cosine_similarity
from collections import defaultdict
import nltk


def get_gene_list():
    with open("input/C_merged_PD_in_CR_trunc_clean_synonyms_B_genes_trunc.txt", "r", encoding='utf8') as f:

        vocab = defaultdict(int)
        for line in f:
            if len(line.strip()) > 0:
                c = line.split()[1]
                text = " ".join(line.split()[2:]).strip()
                text = " ".join(nltk.wordpunct_tokenize(text)).lower()
                if c == "!pd":
                    words = text.split()
                    for w in words:
                        vocab[w] += 1

        vocab = sorted(list(vocab.items()), reverse=True, key=lambda x: x[1])
        vocab = [x[0] for x in vocab]
        return set(vocab)


def load_fasttext(emb_path, nmax=1000000):
    vectors = []
    word2id = {}
    with io.open(emb_path, 'r', encoding='utf-8', newline='\n', errors='ignore') as f:
        next(f)
        for i, line in enumerate(f):
            word, vect = line.rstrip().split(' ', 1)
            vect = np.fromstring(vect, sep=' ')
            assert word not in word2id, 'word found twice'
            vectors.append(vect)
            word2id[word] = len(word2id)
            if len(word2id) == nmax:
                break
    id2word = {v: k for k, v in word2id.items()}
    embeddings = np.vstack(vectors)
    return embeddings, id2word, word2id

def get_emb(word, emb, word2id):
    avg_emb = []
    for word_part in word.split():
        word_emb = emb[word2id[word_part.lower()]].tolist()
        avg_emb.append(word_emb)
    avg = np.average(np.array(avg_emb), axis=0)
    word_emb = avg
    return word_emb

def embeds_to_dict(emb, word2id):
    dict = {}
    words = list(word2id.items())
    for w, id in words:
        dict[w] = emb[id]
    return dict

def get_most_similar(word, word_emb, embeds, n = 10, word_list=[]):
    neigh = []
    items = list(embeds.items())
    values = [v for k, v in items]
    keys = [k for k, v in items]
    #print(np.array(values).shape)
    cs = cosine_similarity(word_emb.reshape(1, -1), np.array(values)).squeeze()
    for i in range(len(keys)):
        neigh.append((keys[i], cs[i]))
    neigh = sorted(neigh, key=lambda x: x[1], reverse=True)
    counter = 0
    word_results = []
    emb_results = []
    for w, score in neigh:
        if word.lower() not in w.lower() and w.lower() not in word.lower():
            if len(word_list) == 0 or w in word_list:
                if counter >= n:
                    break
                counter += 1
                word_results.append((w, score))
                emb_results.append(embeds[w])
    return word_results, emb_results


def get_all_relations(embeds, word2id):
    gene_list = get_gene_list()
    words = list(word2id.keys())
    words = [x for x in words if x in gene_list]
    diffs = {}
    print("calculating all differences: ", len(words) * len(words))
    counter = 0

    for i in range(len(words)):
        for j in range(i + 1, len(words)):
            word_1 = words[i]
            word_2 = words[j]
            emb_1 = embeds[word2id[word_1]]
            emb_2 = embeds[word2id[word_2]]
            diffs[word_1 + '-' + word_2] = emb_1 + emb_2
            #diffs[word_2 + '-' + word_1] = emb_2 + emb_1
            counter += 1
            if counter % 1000000 == 0:
                print("processing diff: ", counter)
    print("Done")
    return diffs




def get_same_relations_in_domain_2(embeds_1, word2id_1, relations_1, embeds_2, word2id_2):

    diffs = get_all_relations(embeds_2, word2id_2)

    for rel in relations_1:
        el1, el2 = rel
        emb_1 = get_emb(el1, embeds_1, word2id_1)
        emb_2 = get_emb(el2, embeds_1, word2id_1)
        emb_rel = emb_1 + emb_2
        word_res, emb_res = get_most_similar(el1 + '-' + el2.lower(), emb_rel, diffs, n=10, word_list=[])
        print("Circadian rhythm: ", el1 + " rel. " + el2)
        print("Most similar plant defense rel:\n")
        print("rank\trelation\tcosine sim.")
        for idx, w in enumerate(word_res):
            score = w[1]
            w = w[0]
            w = w.replace('-', ' rel. ')
            print(str(idx + 1) + '.' + '\t' + w + "\t{:.4f}".format(score))
        print('------------------------------------------')
        print()


def get_analogy(word_1, embeds_1, word2id_1, genes_1, word_2, embeds_2, word2id_2):

    emb_1 = get_emb(word_1, embeds_1, word2id_1)
    emb_2 = get_emb(word_2, embeds_2, word2id_2)
    embeds_2 = embeds_to_dict(embeds_2, word2id_2)

    for gene in genes_1:
        emb_gene = get_emb(gene, embeds_1, word2id_1)
        emb_result = emb_1 + emb_gene - emb_2
        word_res, emb_res = get_most_similar(word_2.lower(), emb_result, embeds_2, n=10, word_list=get_gene_list())
        print("Circadian rhythm domain: ", word_1 + ' rel. ' + gene.lower())
        print("Most similar in plant defense domain:\n")
        print('rank\trelation\tcosine sim.')
        for idx, w in enumerate(word_res):
            score = w[1]
            w = w[0]
            w = 'plant defense rel. ' + w
            print(str(idx + 1) + '.' + '\t' + w + "\t{:.4f}".format(score))
        print('------------------------------------------')
        print()


#Set our seed relations
relations_1 = [['CCA1', 'PRR7'],
               ['CCA1', 'PRR9'],
               ['CCA1', 'PRR5'],
               ['CCA1', 'TOC1'],
               ['CCA1', 'ELF3'],
               ['CCA1', 'ELF4'],
               ['CCA1', 'LUX'],
               ['LHY', 'PRR7'],
               ['LHY', 'PRR9'],
               ['LHY', 'PRR5'],
               ['LHY', 'TOC1'],
               ['LHY', 'ELF3'],
               ['LHY', 'ELF4'],
               ['LHY', 'LUX']]

#Path to aligned embedding models. 
path_1 = 'embeddings/vectors-cr.txt'
path_2 = 'embeddings/vectors-pd.txt'
nmax = 500000  # maximum number of word embeddings to load
embeds_1, id2word_1, word2id_1 = load_fasttext(path_1, nmax)
embeds_2, id2word_2, word2id_2 = load_fasttext(path_2, nmax)
get_same_relations_in_domain_2(embeds_1, word2id_1, relations_1, embeds_2, word2id_2)
# Out:
# calculating all differences:  2424249
# processing diff:  1000000
# Done
# Circadian rhythm:  CCA1 rel. PRR7
# Most similar plant defense rel:
#
# rank	relation	cosine sim.
# 1.	sni1 rel. hsfa1b	0.7390
# 2.	dbp1 rel. tga4	0.7366
# 3.	bon1 rel. tga4	0.7366
# 4.	sni1 rel. dbp1	0.7355
# 5.	nim1 rel. bhlh	0.7350
# 6.	bhlh rel. sni1	0.7347
# 7.	tga6 rel. bon1	0.7329
# 8.	tga6 rel. dbp1	0.7304
# 9.	soc1 rel. tga4	0.7302
# 10.	tga4 rel. rho	0.7298
# ------------------------------------------
#
# Circadian rhythm:  CCA1 rel. PRR9
# Most similar plant defense rel:
#
# rank	relation	cosine sim.
# 1.	dbp1 rel. tga4	0.7462
# 2.	sni1 rel. hsfa1b	0.7456
# 3.	bon1 rel. tga4	0.7450
# 4.	nim1 rel. bhlh	0.7448
# 5.	tga4 rel. rho	0.7430
# 6.	tga rel. hrs1	0.7417
# 7.	tga6 rel. bon1	0.7405
# 8.	sni1 rel. dbp1	0.7403
# 9.	tga6 rel. dbp1	0.7390
# 10.	rpm1 rel. tga	0.7389
# ------------------------------------------
#
# Circadian rhythm:  CCA1 rel. PRR5
# Most similar plant defense rel:
#
# rank	relation	cosine sim.
# 1.	sni1 rel. hsfa1b	0.7460
# 2.	bhlh rel. sni1	0.7405
# 3.	dbp1 rel. tga4	0.7405
# 4.	soc1 rel. tga4	0.7384
# 5.	cpr30 rel. dre	0.7381
# 6.	sni1 rel. dbp1	0.7368
# 7.	sni1 rel. vip1	0.7368
# 8.	tga4 rel. hsfa1b	0.7354
# 9.	bon1 rel. tga4	0.7343
# 10.	sni1 rel. dre	0.7339
# ------------------------------------------
#
# Circadian rhythm:  CCA1 rel. TOC1
# Most similar plant defense rel:
#
# rank	relation	cosine sim.
# 1.	bon1 rel. tga4	0.7321
# 2.	tga6 rel. bon1	0.7277
# 3.	bhlh rel. fld	0.7267
# 4.	tga rel. bon1	0.7259
# 5.	dbp1 rel. tga4	0.7236
# 6.	nim1 rel. bhlh	0.7228
# 7.	tga rel. nfya5	0.7221
# 8.	cpr30 rel. dre	0.7208
# 9.	bhlh rel. cpr30	0.7176
# 10.	rpm1 rel. tga	0.7175
# ------------------------------------------
#
# Circadian rhythm:  CCA1 rel. ELF3
# Most similar plant defense rel:
#
# rank	relation	cosine sim.
# 1.	bhlh rel. fld	0.7496
# 2.	nac rel. flc	0.7484
# 3.	fld rel. dre	0.7452
# 4.	nac rel. fld	0.7397
# 5.	strawberry rel. flc	0.7396
# 6.	fld rel. taf1	0.7393
# 7.	fld rel. erf5	0.7393
# 8.	locus rel. nfya5	0.7389
# 9.	fld rel. hsfa1b	0.7384
# 10.	fld rel. bhlh122	0.7383
# ------------------------------------------
#
# Circadian rhythm:  CCA1 rel. ELF4
# Most similar plant defense rel:
#
# rank	relation	cosine sim.
# 1.	bhlh rel. fld	0.7483
# 2.	cpr30 rel. dre	0.7478
# 3.	fld rel. dre	0.7403
# 4.	bon1 rel. tga4	0.7381
# 5.	tga6 rel. bon1	0.7378
# 6.	rpp4 rel. nfya5	0.7373
# 7.	rps5 rel. nfya5	0.7369
# 8.	nfya5 rel. rpi1	0.7345
# 9.	nfya5 rel. bon1	0.7337
# 10.	rpp8 rel. nfya5	0.7336
# ------------------------------------------
#
# Circadian rhythm:  CCA1 rel. LUX
# Most similar plant defense rel:
#
# rank	relation	cosine sim.
# 1.	rp1 rel. nfya5	0.6916
# 2.	nfya5 rel. rpp14	0.6864
# 3.	rpp8 rel. nfya5	0.6842
# 4.	rp1 rel. tga3	0.6821
# 5.	nfya5 rel. rpi1	0.6808
# 6.	natural rel. nfya5	0.6797
# 7.	rp1 rel. abi5	0.6794
# 8.	natural rel. tga3	0.6778
# 9.	rps5 rel. nfya5	0.6770
# 10.	rp1 rel. ap2	0.6769
# ------------------------------------------
#
# Circadian rhythm:  LHY rel. PRR7
# Most similar plant defense rel:
#
# rank	relation	cosine sim.
# 1.	rps5 rel. abi5	0.7392
# 2.	duplicated rel. abi1	0.7388
# 3.	rpp4 rel. tga4	0.7365
# 4.	tga6 rel. bon1	0.7361
# 5.	rpp4 rel. tga	0.7357
# 6.	srfr1 rel. tga4	0.7354
# 7.	sni1 rel. dbp1	0.7353
# 8.	bon1 rel. tga4	0.7344
# 9.	sni1 rel. hsfa1b	0.7314
# 10.	abi5 rel. sni1	0.7308
# ------------------------------------------
#
# Circadian rhythm:  LHY rel. PRR9
# Most similar plant defense rel:
#
# rank	relation	cosine sim.
# 1.	srfr1 rel. tga4	0.7500
# 2.	rps5 rel. abi5	0.7472
# 3.	tga6 rel. bon1	0.7470
# 4.	srfr1 rel. tga	0.7464
# 5.	bon1 rel. tga4	0.7461
# 6.	sni1 rel. dbp1	0.7434
# 7.	rpp4 rel. tga	0.7416
# 8.	srfr1 rel. tga6	0.7412
# 9.	sni1 rel. hsfa1b	0.7412
# 10.	rps5 rel. nfya5	0.7407
# ------------------------------------------
#
# Circadian rhythm:  LHY rel. PRR5
# Most similar plant defense rel:
#
# rank	relation	cosine sim.
# 1.	sni1 rel. hsfa1b	0.7434
# 2.	rps5 rel. abi5	0.7431
# 3.	sni1 rel. dbp1	0.7418
# 4.	sni1 rel. soc1	0.7415
# 5.	abi5 rel. sni1	0.7407
# 6.	bon1 rel. tga4	0.7372
# 7.	tga6 rel. bon1	0.7360
# 8.	bhlh rel. sni1	0.7352
# 9.	srfr1 rel. tga4	0.7345
# 10.	rps5 rel. nfya5	0.7345
# ------------------------------------------
#
# Circadian rhythm:  LHY rel. TOC1
# Most similar plant defense rel:
#
# rank	relation	cosine sim.
# 1.	tga6 rel. bon1	0.7355
# 2.	bon1 rel. tga4	0.7345
# 3.	flowering rel. tga4	0.7268
# 4.	flowering rel. tga1	0.7268
# 5.	flowering rel. sni1	0.7256
# 6.	bhlh rel. fld	0.7255
# 7.	rpm1 rel. ap2	0.7250
# 8.	rpp4 rel. tga	0.7248
# 9.	sni1 rel. bon1	0.7245
# 10.	rpp4 rel. nfya5	0.7243
# ------------------------------------------
#
# Circadian rhythm:  LHY rel. ELF3
# Most similar plant defense rel:
#
# rank	relation	cosine sim.
# 1.	fld rel. taf1	0.7531
# 2.	rpp4 rel. myb44	0.7472
# 3.	fld rel. bon1	0.7455
# 4.	srfr1 rel. flc	0.7449
# 5.	rpp4 rel. fld	0.7449
# 6.	flowering rel. rps5	0.7442
# 7.	fld rel. abi5	0.7437
# 8.	flower rel. rps5	0.7434
# 9.	bhlh rel. fld	0.7434
# 10.	rps5 rel. fld	0.7430
# ------------------------------------------
#
# Circadian rhythm:  LHY rel. ELF4
# Most similar plant defense rel:
#
# rank	relation	cosine sim.
# 1.	rpp4 rel. nfya5	0.7569
# 2.	rpp4 rel. myb44	0.7527
# 3.	rpp8 rel. myb44	0.7511
# 4.	rpp8 rel. nfya5	0.7486
# 5.	rpp1 rel. nfya5	0.7447
# 6.	bhlh rel. fld	0.7433
# 7.	sni1 rel. bon1	0.7430
# 8.	tga6 rel. bon1	0.7428
# 9.	rps5 rel. nfya5	0.7426
# 10.	rpp4 rel. fld	0.7423
# ------------------------------------------
#
# Circadian rhythm:  LHY rel. LUX
# Most similar plant defense rel:
#
# rank	relation	cosine sim.
# 1.	nfya5 rel. rpp14	0.7118
# 2.	rpp8 rel. nfya5	0.7032
# 3.	rpp8 rel. apum23	0.7027
# 4.	rp1 rel. abi5	0.7009
# 5.	rp1 rel. nfya5	0.6983
# 6.	rp1 rel. ap2	0.6977
# 7.	rpp8 rel. abi5	0.6963
# 8.	rpp8 rel. bhlh122	0.6948
# 9.	rpp1 rel. nfya5	0.6917
# 10.	circadian rel. rps5	0.6914
# ------------------------------------------

# %% [markdown]
# To get exactly the same results as in the paper (reproducibility of results), use the files 'cr-aligned-original.vec' and 'pd-aligned-original.vec' in the embedding folder instead of the generated aligned embeddings. To do this, change the file names to the original embedding files.

# %%
# If you want to exactly reproduce the results in the paper, instead use the 'cr-aligned-original.vec' and 'pd-aligned-original.vec' files in the embedding folder.
path_1 = 'embeddings/cr-aligned-original.vec'
path_2 = 'embeddings/pd-aligned-original.vec'
nmax = 500000  # maximum number of word embeddings to load
embeds_1, id2word_1, word2id_1 = load_fasttext(path_1, nmax)
embeds_2, id2word_2, word2id_2 = load_fasttext(path_2, nmax)
get_same_relations_in_domain_2(embeds_1, word2id_1, relations_1, embeds_2, word2id_2)
